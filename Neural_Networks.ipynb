# %% [markdown]
# ## 7 Neural networks for a complex decision boundary
# ### Yash Raichura

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.neural_network import MLPClassifier
import numpy as np

# %% [markdown]
# ### 1. Create Data

# %%
n = 500 # how many points
x1 = np.random.normal(size=n)
x2 = np.random.normal(size=n)
alpha = np.arctan2(x2, x1)
r = np.sqrt(x1**2 + x2**2)
c1 = (np.sin(2*alpha + 2*r) > 0).astype('int')
c2 = (np.cos(2*alpha + 2*r) > 0).astype('int')
c = c1 + c2 # this is your target
## features, target:
X = np.column_stack((x1,x2))
y = c
## this is how the data looks like
plt.figure(figsize=(9,9))
plt.scatter(x1, x2, c=c, s=100, edgecolors='k')
plt.show()

# %% [markdown]
# ### 2 Categorize

# %%
m = MLPClassifier(hidden_layer_sizes = (5,),
activation="relu",alpha=0.001, tol=1e-6).fit(X, y)
## Predict: take this code as black box
## /home/siim/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
## % self.max_iter, ConvergenceWarning)
range1 = np.linspace(X[:,0].min(), X[:,0].max(), 100)
range2 = np.linspace(X[:,1].min(), X[:,1].max(), 100)
(xx1, xx2) = np.meshgrid(range1, range2)
Xgrid = np.column_stack((xx1.ravel(), xx2.ravel()))
yhat = m.predict(Xgrid)
plt.figure(figsize=(10,10))
## plot the predicted values on grid as an image
plt.imshow(yhat.reshape((100,100)),
alpha=0.3, extent=[xx1.min(), xx1.max(), xx2.min(), xx2.max()],
origin='lower', aspect='auto')
## add the actual values
plt.scatter(X[:,0], X[:,1], c=y, s=100, alpha=0.7, edgecolor="k")
plt.xlabel("X1")
plt.ylabel("X2")
# Out:
# C:\Users\Purba\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Text(0, 0.5, 'X2')

# %% [markdown]
# ### 3. As you can see, the neural network made a miserable job predicting the data correctly. Can you adjust the parameters to make it to match better?
# ### 4. Experiment with single and multiple hidden layers.

# %% [markdown]
# #### altering the nerual network by having 1 hidden layer with 20 hidden units

# %%
m = MLPClassifier(hidden_layer_sizes = (20,),
activation="relu",alpha=1, tol=1e-6).fit(X, y)
## Predict: take this code as black box
## /home/siim/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
## % self.max_iter, ConvergenceWarning)
range1 = np.linspace(X[:,0].min(), X[:,0].max(), 100)
range2 = np.linspace(X[:,1].min(), X[:,1].max(), 100)
(xx1, xx2) = np.meshgrid(range1, range2)
Xgrid = np.column_stack((xx1.ravel(), xx2.ravel()))
yhat = m.predict(Xgrid)
plt.figure(figsize=(10,10))
## plot the predicted values on grid as an image
plt.imshow(yhat.reshape((100,100)),
alpha=0.3, extent=[xx1.min(), xx1.max(), xx2.min(), xx2.max()],
origin='lower', aspect='auto')
## add the actual values
plt.scatter(X[:,0], X[:,1], c=y, s=100, alpha=0.7, edgecolor="k")
plt.xlabel("X1")
plt.ylabel("X2")
# Out:
# C:\Users\Purba\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Text(0, 0.5, 'X2')

# %% [markdown]
# #### Increasing the number of hidden layers to 2 with 20 hidden units each

# %%
m = MLPClassifier(hidden_layer_sizes = (20,20),
activation="relu",alpha=1, tol=1e-6).fit(X, y)
## Predict: take this code as black box
## /home/siim/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
## % self.max_iter, ConvergenceWarning)
range1 = np.linspace(X[:,0].min(), X[:,0].max(), 100)
range2 = np.linspace(X[:,1].min(), X[:,1].max(), 100)
(xx1, xx2) = np.meshgrid(range1, range2)
Xgrid = np.column_stack((xx1.ravel(), xx2.ravel()))
yhat = m.predict(Xgrid)
plt.figure(figsize=(10,10))
## plot the predicted values on grid as an image
plt.imshow(yhat.reshape((100,100)),
alpha=0.3, extent=[xx1.min(), xx1.max(), xx2.min(), xx2.max()],
origin='lower', aspect='auto')
## add the actual values
plt.scatter(X[:,0], X[:,1], c=y, s=100, alpha=0.7, edgecolor="k")
plt.xlabel("X1")
plt.ylabel("X2")
# Out:
# C:\Users\Purba\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Text(0, 0.5, 'X2')

# %% [markdown]
# #### Increasing the number of layers to 3, and 40 hidden units

# %%
m = MLPClassifier(hidden_layer_sizes = (40,40,40),
activation="relu",alpha=1, tol=1e-6).fit(X, y)
## Predict: take this code as black box
## /home/siim/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
## % self.max_iter, ConvergenceWarning)
range1 = np.linspace(X[:,0].min(), X[:,0].max(), 100)
range2 = np.linspace(X[:,1].min(), X[:,1].max(), 100)
(xx1, xx2) = np.meshgrid(range1, range2)
Xgrid = np.column_stack((xx1.ravel(), xx2.ravel()))
yhat = m.predict(Xgrid)
plt.figure(figsize=(10,10))
## plot the predicted values on grid as an image
plt.imshow(yhat.reshape((100,100)),
alpha=0.3, extent=[xx1.min(), xx1.max(), xx2.min(), xx2.max()],
origin='lower', aspect='auto')
## add the actual values
plt.scatter(X[:,0], X[:,1], c=y, s=100, alpha=0.5, edgecolor="k")
plt.xlabel("X1")
plt.ylabel("X2")
# Out:
# C:\Users\Purba\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Text(0, 0.5, 'X2')

# %% [markdown]
# #### Increasing the number of hidden layers to 3, and 70 hidden units**

# %%
m = MLPClassifier(hidden_layer_sizes = (70,70,70),
activation="relu",alpha=1, tol=1e-6).fit(X, y)
## Predict: take this code as black box
## /home/siim/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
## % self.max_iter, ConvergenceWarning)
range1 = np.linspace(X[:,0].min(), X[:,0].max(), 100)
range2 = np.linspace(X[:,1].min(), X[:,1].max(), 100)
(xx1, xx2) = np.meshgrid(range1, range2)
Xgrid = np.column_stack((xx1.ravel(), xx2.ravel()))
yhat = m.predict(Xgrid)
plt.figure(figsize=(10,10))
## plot the predicted values on grid as an image
plt.imshow(yhat.reshape((100,100)),
alpha=0.3, extent=[xx1.min(), xx1.max(), xx2.min(), xx2.max()],
origin='lower', aspect='auto')
## add the actual values
plt.scatter(X[:,0], X[:,1], c=y, s=100, alpha=0.7, edgecolor="k")
plt.xlabel("X1")
plt.ylabel("X2")
# Out:
# C:\Users\Purba\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Text(0, 0.5, 'X2')

# %% [markdown]
# #### Increasing the numebr of layers to 3, and 80 hidden units in the first layer, 60 in the second, and 40 in the 3rd hidden layer.
#
# We see that for a few points, the model is performing better than the previous model, however it is not true for all the predicted categoris of data points.

# %%
m = MLPClassifier(hidden_layer_sizes = (80,60,40),
activation="relu",alpha=1, tol=1e-6).fit(X, y)
## Predict: take this code as black box
## /home/siim/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
## % self.max_iter, ConvergenceWarning)
range1 = np.linspace(X[:,0].min(), X[:,0].max(), 100)
range2 = np.linspace(X[:,1].min(), X[:,1].max(), 100)
(xx1, xx2) = np.meshgrid(range1, range2)
Xgrid = np.column_stack((xx1.ravel(), xx2.ravel()))
yhat = m.predict(Xgrid)
plt.figure(figsize=(10,10))
## plot the predicted values on grid as an image
plt.imshow(yhat.reshape((100,100)),
alpha=0.3, extent=[xx1.min(), xx1.max(), xx2.min(), xx2.max()],
origin='lower', aspect='auto')
## add the actual values
plt.scatter(X[:,0], X[:,1], c=y, s=100, alpha=0.7, edgecolor="k")
plt.xlabel("X1")
plt.ylabel("X2")
# Out:
# C:\Users\Purba\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Text(0, 0.5, 'X2')

# %% [markdown]
# #### If there is an increase in alpha, the model becomes a highly biased model and is unable to predict accurately. We demonstrate that below:

# %%
m = MLPClassifier(hidden_layer_sizes = (100,100,90),
activation="relu",alpha=10, tol=1e-6).fit(X, y)
## Predict: take this code as black box
## /home/siim/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
## % self.max_iter, ConvergenceWarning)
range1 = np.linspace(X[:,0].min(), X[:,0].max(), 100)
range2 = np.linspace(X[:,1].min(), X[:,1].max(), 100)
(xx1, xx2) = np.meshgrid(range1, range2)
Xgrid = np.column_stack((xx1.ravel(), xx2.ravel()))
yhat = m.predict(Xgrid)
plt.figure(figsize=(10,10))
## plot the predicted values on grid as an image
plt.imshow(yhat.reshape((100,100)),
alpha=0.3, extent=[xx1.min(), xx1.max(), xx2.min(), xx2.max()],
origin='lower', aspect='auto')
## add the actual values
plt.scatter(X[:,0], X[:,1], c=y, s=100, alpha=0.7, edgecolor="k")
plt.xlabel("X1")
plt.ylabel("X2")
# Out:
# C:\Users\Purba\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Text(0, 0.5, 'X2')
